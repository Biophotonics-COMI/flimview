# %%
# %load_ext autoreload
# %autoreload 2
from .. import flim as flim
import matplotlib.pyplot as plt
from matplotlib import cm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7dc3bdb562a6> in <module>
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from .. import flim as flim
#       4 import matplotlib.pyplot as plt
#       5 from matplotlib import cm
#
# ValueError: attempted relative import beyond top-level package

# %%
bbin = 4

# %%
# linear
k1 = flim.getKernel(bin=bbin, kernel='linear')
plt.imshow(k1)
plt.title('linear')
plt.colorbar()

# %%
# gauss
k2 = flim.getKernel(bin=bbin, kernel='gauss')
plt.imshow(k2)
plt.title('gauss, sigma=(bin+1)/3')
plt.colorbar()

# %%
# gauss, kernels
k3 = flim.getKernel(bin=bbin, kernel='gauss', sigma=8)
plt.imshow(k3)
plt.title('gauss')
plt.colorbar()

# %%
# gauss, kernels
k4 = flim.getKernel(bin=bbin, kernel='gauss', sigma=2)
plt.imshow(k4)
plt.title('gauss')
plt.colorbar()

# %%
# airy disk
k5 = flim.getKernel(bin=bbin, kernel='airy')
plt.imshow(k5)
plt.title('airy')
plt.colorbar()

# %%
# airy disk
k6 = flim.getKernel(bin=bbin, kernel='airy', sigma=8)
plt.imshow(k6)
plt.title('airy')
plt.colorbar()
